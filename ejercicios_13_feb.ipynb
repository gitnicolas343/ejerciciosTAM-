# %% [markdown]
# <a href="https://colab.research.google.com/github/gitnicolas343/ejerciciosTAM-/blob/main/ejercicios_13_feb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def add_gaussian_noise(images, snr_db):
    signal_power = np.mean(images ** 2)
    noise_power = signal_power / (10 ** (snr_db / 10))
    noise = np.random.normal(scale=np.sqrt(noise_power), size=images.shape)
    return np.clip(images + noise, 0, 1)

def add_salt_and_pepper_noise(images, amount=0.02):
    noisy_images = images.copy()
    num_pixels = int(amount * images.shape[1] * images.shape[2])
    for img in noisy_images:
        coords = [np.random.randint(0, i, num_pixels) for i in img.shape]
        img[coords[0], coords[1]] = np.random.choice([0, 1])
    return noisy_images

(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
X_train, X_valid = X_train_full[:-5000] / 255.0, X_train_full[-5000:] / 255.0
y_train, y_valid = y_train_full[:-5000], y_train_full[-5000:]

X_train = X_train[..., np.newaxis]
X_valid = X_valid[..., np.newaxis]
X_test = X_test[..., np.newaxis]

X_train_gaussian = add_gaussian_noise(X_train, snr_db=3)
X_train_sp = add_salt_and_pepper_noise(X_train, amount=0.02)
X_valid_gaussian = add_gaussian_noise(X_valid, snr_db=3)
X_valid_sp = add_salt_and_pepper_noise(X_valid, amount=0.02)

gender_labels = {0: 2, 1: 2, 2: 0, 3: 1, 4: 0, 5: 1, 6: 0, 7: 2, 8: 1, 9: 2}
y_train_gender = np.array([gender_labels[label] for label in y_train])
y_valid_gender = np.array([gender_labels[label] for label in y_valid])

input_clean = keras.Input(shape=(28, 28, 1), name="input_clean")
input_gaussian = keras.Input(shape=(28, 28, 1), name="input_gaussian")
input_sp = keras.Input(shape=(28, 28, 1), name="input_sp")

def autoencoder_block(input_layer):
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_layer)
    x = layers.MaxPooling2D((2, 2), padding='same')(x)
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    encoded = layers.MaxPooling2D((2, 2), padding='same')(x)
    return encoded

encoded_clean = autoencoder_block(input_clean)
encoded_gaussian = autoencoder_block(input_gaussian)
encoded_sp = autoencoder_block(input_sp)

merged = layers.Concatenate()([encoded_clean, encoded_gaussian, encoded_sp])

def decoder_block(encoded_input):
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(encoded_input)
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.UpSampling2D((2, 2))(x)
    decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same', name="output_reconstructed")(x)
    return decoded

output_reconstructed = decoder_block(merged)

x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(merged)
x = layers.Flatten()(x)
x = layers.Dense(128, activation='relu')(x)

output_class = layers.Dense(10, activation='softmax', name="output_class")(x)
output_gender = layers.Dense(3, activation='softmax', name="output_gender")(x)

model = keras.Model(inputs=[input_clean, input_gaussian, input_sp], outputs=[output_class, output_gender, output_reconstructed])

model.compile(optimizer='adam',
              loss={'output_class': 'sparse_categorical_crossentropy', 'output_gender': 'sparse_categorical_crossentropy', 'output_reconstructed': 'mse'},
              metrics={'output_class': 'accuracy', 'output_gender': 'accuracy', 'output_reconstructed': 'mse'})

model.summary()

# Entrenamiento del modelo
history = model.fit([X_train, X_train_gaussian, X_train_sp], [y_train, y_train_gender, X_train],
                    epochs=10, batch_size=128, validation_data=([X_valid, X_valid_gaussian, X_valid_sp], [y_valid, y_valid_gender, X_valid]))

# Evaluación del modelo
y_pred_class, y_pred_gender, _ = model.predict([X_test, add_gaussian_noise(X_test, snr_db=3), add_salt_and_pepper_noise(X_test, amount=0.02)])
y_pred_class = np.argmax(y_pred_class, axis=1)
y_pred_gender = np.argmax(y_pred_gender, axis=1)

# Etiquetas para Fashion MNIST
class_labels = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
gender_labels = ["Masculino", "Femenino", "Neutro"]

# Matrices de confusión y reportes de clasificación
def plot_confusion_matrix(y_true, y_pred, title, labels):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title(title)
    plt.show()

print("Classification Report - Clothing Classes")
print(classification_report(y_test, y_pred_class, target_names=class_labels))
plot_confusion_matrix(y_test, y_pred_class, "Confusion Matrix - Clothing Classes", class_labels)

print("Classification Report - Gender Classes")
print(classification_report(y_train_gender[:len(y_pred_gender)], y_pred_gender, target_names=gender_labels))
plot_confusion_matrix(y_train_gender[:len(y_pred_gender)], y_pred_gender, "Confusion Matrix - Gender Classes", gender_labels)
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_clean (InputLayer)  │ (None, 28, 28, 1)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_gaussian            │ (None, 28, 28, 1)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_sp (InputLayer)     │ (None, 28, 28, 1)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_48 (Conv2D)        │ (None, 28, 28, 32)     │            320 │ input_clean[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_50 (Conv2D)        │ (None, 28, 28, 32)     │            320 │ input_gaussian[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_52 (Conv2D)        │ (None, 28, 28, 32)     │            320 │ input_sp[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_36          │ (None, 14, 14, 32)     │              0 │ conv2d_48[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_38          │ (None, 14, 14, 32)     │              0 │ conv2d_50[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_40          │ (None, 14, 14, 32)     │              0 │ conv2d_52[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_49 (Conv2D)        │ (None, 14, 14, 64)     │         18,496 │ max_pooling2d_36[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_51 (Conv2D)        │ (None, 14, 14, 64)     │         18,496 │ max_pooling2d_38[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_53 (Conv2D)        │ (None, 14, 14, 64)     │         18,496 │ max_pooling2d_40[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_37          │ (None, 7, 7, 64)       │              0 │ conv2d_49[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_39          │ (None, 7, 7, 64)       │              0 │ conv2d_51[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_41          │ (None, 7, 7, 64)       │              0 │ conv2d_53[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_6             │ (None, 7, 7, 192)      │              0 │ max_pooling2d_37[0][0… │
# │ (Concatenate)             │                        │                │ max_pooling2d_39[0][0… │
# │                           │                        │                │ max_pooling2d_41[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_54 (Conv2D)        │ (None, 7, 7, 64)       │        110,656 │ concatenate_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_56 (Conv2D)        │ (None, 7, 7, 128)      │        221,312 │ concatenate_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_6           │ (None, 14, 14, 64)     │              0 │ conv2d_54[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_6 (Flatten)       │ (None, 6272)           │              0 │ conv2d_56[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_55 (Conv2D)        │ (None, 14, 14, 32)     │         18,464 │ up_sampling2d_6[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 128)            │        802,944 │ flatten_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_7           │ (None, 28, 28, 32)     │              0 │ conv2d_55[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_class (Dense)      │ (None, 10)             │          1,290 │ dense_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_gender (Dense)     │ (None, 3)              │            387 │ dense_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_reconstructed      │ (None, 28, 28, 1)      │            289 │ up_sampling2d_7[0][0]  │
# │ (Conv2D)                  │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,211,790 (4.62 MB)
#  Trainable params: 1,211,790 (4.62 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 18s 25ms/step - loss: 1.1348 - output_class_accuracy: 0.7329 - output_class_loss: 0.7325 - output_gender_accuracy: 0.8407 - output_gender_loss: 0.3711 - output_reconstructed_loss: 0.0312 - output_reconstructed_mse: 0.0312 - val_loss: 0.5078 - val_output_class_accuracy: 0.8794 - val_output_class_loss: 0.3197 - val_output_gender_accuracy: 0.9300 - val_output_gender_loss: 0.1683 - val_output_reconstructed_loss: 0.0099 - val_output_reconstructed_mse: 0.0098
# Epoch 2/10
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 0.4652 - output_class_accuracy: 0.8896 - output_class_loss: 0.3048 - output_gender_accuracy: 0.9427 - output_gender_loss: 0.1512 - output_reconstructed_loss: 0.0091 - output_reconstructed_mse: 0.0091 - val_loss: 0.3912 - val_output_class_accuracy: 0.9042 - val_output_class_loss: 0.2504 - val_output_gender_accuracy: 0.9490 - val_output_gender_loss: 0.1252 - val_output_reconstructed_loss: 0.0072 - val_output_reconstructed_mse: 0.0072
# Epoch 3/10
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.3650 - output_class_accuracy: 0.9129 - output_class_loss: 0.2422 - output_gender_accuracy: 0.9547 - output_gender_loss: 0.1160 - output_reconstructed_loss: 0.0068 - output_reconstructed_mse: 0.0068 - val_loss: 0.3611 - val_output_class_accuracy: 0.9104 - val_output_class_loss: 0.2332 - val_output_gender_accuracy: 0.9536 - val_output_gender_loss: 0.1140 - val_output_reconstructed_loss: 0.0059 - val_output_reconstructed_mse: 0.0059
# Epoch 4/10
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 0.3241 - output_class_accuracy: 0.9209 - output_class_loss: 0.2135 - output_gender_accuracy: 0.9582 - output_gender_loss: 0.1048 - output_reconstructed_loss: 0.0058 - output_reconstructed_mse: 0.0058 - val_loss: 0.3534 - val_output_class_accuracy: 0.9100 - val_output_class_loss: 0.2285 - val_output_gender_accuracy: 0.9522 - val_output_gender_loss: 0.1117 - val_output_reconstructed_loss: 0.0054 - val_output_reconstructed_mse: 0.0054
# Epoch 5/10
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.2722 - output_class_accuracy: 0.9335 - output_class_loss: 0.1809 - output_gender_accuracy: 0.9663 - output_gender_loss: 0.0860 - output_reconstructed_loss: 0.0053 - output_reconstructed_mse: 0.0053 - val_loss: 0.3469 - val_output_class_accuracy: 0.9182 - val_output_class_loss: 0.2213 - val_output_gender_accuracy: 0.9564 - val_output_gender_loss: 0.1127 - val_output_reconstructed_loss: 0.0051 - val_output_reconstructed_mse: 0.0050
# Epoch 6/10
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 0.2358 - output_class_accuracy: 0.9413 - output_class_loss: 0.1582 - output_gender_accuracy: 0.9717 - output_gender_loss: 0.0726 - output_reconstructed_loss: 0.0050 - output_reconstructed_mse: 0.0050 - val_loss: 0.3409 - val_output_class_accuracy: 0.9200 - val_output_class_loss: 0.2157 - val_output_gender_accuracy: 0.9578 - val_output_gender_loss: 0.1127 - val_output_reconstructed_loss: 0.0047 - val_output_reconstructed_mse: 0.0047
# Epoch 7/10
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.1902 - output_class_accuracy: 0.9534 - output_class_loss: 0.1288 - output_gender_accuracy: 0.9785 - output_gender_loss: 0.0567 - output_reconstructed_loss: 0.0047 - output_reconstructed_mse: 0.0047 - val_loss: 0.3551 - val_output_class_accuracy: 0.9154 - val_output_class_loss: 0.2285 - val_output_gender_accuracy: 0.9572 - val_output_gender_loss: 0.1135 - val_output_reconstructed_loss: 0.0049 - val_output_reconstructed_mse: 0.0049
# Epoch 8/10
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 0.1490 - output_class_accuracy: 0.9617 - output_class_loss: 0.1019 - output_gender_accuracy: 0.9843 - output_gender_loss: 0.0425 - output_reconstructed_loss: 0.0046 - output_reconstructed_mse: 0.0046 - val_loss: 0.3549 - val_output_class_accuracy: 0.9208 - val_output_class_loss: 0.2237 - val_output_gender_accuracy: 0.9570 - val_output_gender_loss: 0.1188 - val_output_reconstructed_loss: 0.0043 - val_output_reconstructed_mse: 0.0043
# Epoch 9/10
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.1208 - output_class_accuracy: 0.9694 - output_class_loss: 0.0854 - output_gender_accuracy: 0.9886 - output_gender_loss: 0.0310 - output_reconstructed_loss: 0.0044 - output_reconstructed_mse: 0.0044 - val_loss: 0.3960 - val_output_class_accuracy: 0.9156 - val_output_class_loss: 0.2450 - val_output_gender_accuracy: 0.9512 - val_output_gender_loss: 0.1375 - val_output_reconstructed_loss: 0.0043 - val_output_reconstructed_mse: 0.0043
# Epoch 10/10
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - loss: 0.0846 - output_class_accuracy: 0.9787 - output_class_loss: 0.0600 - output_gender_accuracy: 0.9929 - output_gender_loss: 0.0204 - output_reconstructed_loss: 0.0042 - output_reconstructed_mse: 0.0042 - val_loss: 0.4419 - val_output_class_accuracy: 0.9180 - val_output_class_loss: 0.2644 - val_output_gender_accuracy: 0.9532 - val_output_gender_loss: 0.1631 - val_output_reconstructed_loss: 0.0042 - val_output_reconstructed_mse: 0.0042
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Classification Report - Clothing Classes
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.88      0.78      0.82      1000
#      Trouser       1.00      0.97      0.98      1000
#     Pullover       0.94      0.65      0.76      1000
#        Dress       0.91      0.89      0.90      1000
#         Coat       0.68      0.93      0.79      1000
#       Sandal       0.96      0.99      0.97      1000
#        Shirt       0.66      0.73      0.69      1000
#      Sneaker       0.95      0.94      0.95      1000
#          Bag       0.96      0.99      0.97      1000
#   Ankle boot       0.98      0.95      0.96      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.89      0.88      0.88     10000
# weighted avg       0.89      0.88      0.88     10000
# Classification Report - Gender Classes
#               precision    recall  f1-score   support
#
#    Masculino       0.29      0.31      0.30      3011
#     Femenino       0.30      0.31      0.31      2998
#       Neutro       0.40      0.37      0.38      3991
#
#     accuracy                           0.33     10000
#    macro avg       0.33      0.33      0.33     10000
# weighted avg       0.34      0.33      0.33     10000

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def add_gaussian_noise(images, snr_db):
    signal_power = np.mean(images ** 2)
    noise_power = signal_power / (10 ** (snr_db / 10))
    noise = np.random.normal(scale=np.sqrt(noise_power), size=images.shape)
    return np.clip(images + noise, 0, 1)

def add_salt_and_pepper_noise(images, amount=0.02):
    noisy_images = images.copy()
    num_pixels = int(amount * images.shape[1] * images.shape[2])
    for img in noisy_images:
        coords = [np.random.randint(0, i, num_pixels) for i in img.shape]
        img[coords[0], coords[1]] = np.random.choice([0, 1])
    return noisy_images

(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
X_train, X_valid = X_train_full[:-5000] / 255.0, X_train_full[-5000:] / 255.0
y_train, y_valid = y_train_full[:-5000], y_train_full[-5000:]

X_train = X_train[..., np.newaxis]
X_valid = X_valid[..., np.newaxis]
X_test = X_test[..., np.newaxis]

X_train_gaussian = add_gaussian_noise(X_train, snr_db=3)
X_train_sp = add_salt_and_pepper_noise(X_train, amount=0.02)
X_valid_gaussian = add_gaussian_noise(X_valid, snr_db=3)
X_valid_sp = add_salt_and_pepper_noise(X_valid, amount=0.02)

gender_labels = {0: 2, 1: 2, 2: 0, 3: 1, 4: 0, 5: 1, 6: 0, 7: 2, 8: 1, 9: 2}
y_train_gender = np.array([gender_labels[label] for label in y_train])
y_valid_gender = np.array([gender_labels[label] for label in y_valid])

input_clean = keras.Input(shape=(28, 28, 1), name="input_clean")
input_gaussian = keras.Input(shape=(28, 28, 1), name="input_gaussian")
input_sp = keras.Input(shape=(28, 28, 1), name="input_sp")

def autoencoder_block(input_layer):
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_layer)
    x = layers.MaxPooling2D((2, 2), padding='same')(x)
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2, 2), padding='same')(x)
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    encoded = layers.MaxPooling2D((2, 2), padding='same')(x)
    return encoded

encoded_clean = autoencoder_block(input_clean)
encoded_gaussian = autoencoder_block(input_gaussian)
encoded_sp = autoencoder_block(input_sp)

merged = layers.Concatenate()([encoded_clean, encoded_gaussian, encoded_sp])

def decoder_block(encoded_input):
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(encoded_input)
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
    decoded = layers.Cropping2D(((2, 2), (2, 2)), name="output_reconstructed")(x)  # Ajuste de tamaño
    return decoded

output_reconstructed = decoder_block(merged)

x_class = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(merged)
x_class = layers.Flatten()(x_class)
x_class = layers.Dense(128, activation='relu')(x_class)
output_class = layers.Dense(10, activation='softmax', name="output_class")(x_class)

x_gender = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(merged)
x_gender = layers.Flatten()(x_gender)
x_gender = layers.Dense(64, activation='relu')(x_gender)
x_gender = layers.Dropout(0.3)(x_gender)
output_gender = layers.Dense(3, activation='softmax', name="output_gender")(x_gender)

model = keras.Model(inputs=[input_clean, input_gaussian, input_sp], outputs=[output_class, output_gender, output_reconstructed])

model.compile(optimizer='adam',
              loss={'output_class': 'sparse_categorical_crossentropy', 'output_gender': 'sparse_categorical_crossentropy', 'output_reconstructed': 'mse'},
              metrics={'output_class': 'accuracy', 'output_gender': 'accuracy', 'output_reconstructed': 'mse'})

model.summary()

# Entrenamiento del modelo
history = model.fit([X_train, X_train_gaussian, X_train_sp], [y_train, y_train_gender, X_train],
                    epochs=20, batch_size=128, validation_data=([X_valid, X_valid_gaussian, X_valid_sp], [y_valid, y_valid_gender, X_valid]))

# Evaluación del modelo
y_pred_class, y_pred_gender, _ = model.predict([X_test, add_gaussian_noise(X_test, snr_db=3), add_salt_and_pepper_noise(X_test, amount=0.02)])
y_pred_class = np.argmax(y_pred_class, axis=1)
y_pred_gender = np.argmax(y_pred_gender, axis=1)

# Etiquetas para Fashion MNIST
class_labels = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]
gender_labels = ["Masculino", "Femenino", "Neutro"]

# Matrices de confusión y reportes de clasificación
def plot_confusion_matrix(y_true, y_pred, title, labels):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title(title)
    plt.show()

print("Classification Report - Clothing Classes")
print(classification_report(y_test, y_pred_class, target_names=class_labels))
plot_confusion_matrix(y_test, y_pred_class, "Confusion Matrix - Clothing Classes", class_labels)

print("Classification Report - Gender Classes")
print(classification_report(y_train_gender[:len(y_pred_gender)], y_pred_gender, target_names=gender_labels))
plot_confusion_matrix(y_train_gender[:len(y_pred_gender)], y_pred_gender, "Confusion Matrix - Gender Classes", gender_labels)
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_clean (InputLayer)  │ (None, 28, 28, 1)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_gaussian            │ (None, 28, 28, 1)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_sp (InputLayer)     │ (None, 28, 28, 1)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_71 (Conv2D)        │ (None, 28, 28, 32)     │            320 │ input_clean[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_74 (Conv2D)        │ (None, 28, 28, 32)     │            320 │ input_gaussian[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_77 (Conv2D)        │ (None, 28, 28, 32)     │            320 │ input_sp[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_51          │ (None, 14, 14, 32)     │              0 │ conv2d_71[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_54          │ (None, 14, 14, 32)     │              0 │ conv2d_74[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_57          │ (None, 14, 14, 32)     │              0 │ conv2d_77[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_72 (Conv2D)        │ (None, 14, 14, 64)     │         18,496 │ max_pooling2d_51[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_75 (Conv2D)        │ (None, 14, 14, 64)     │         18,496 │ max_pooling2d_54[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_78 (Conv2D)        │ (None, 14, 14, 64)     │         18,496 │ max_pooling2d_57[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_52          │ (None, 7, 7, 64)       │              0 │ conv2d_72[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_55          │ (None, 7, 7, 64)       │              0 │ conv2d_75[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_58          │ (None, 7, 7, 64)       │              0 │ conv2d_78[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_73 (Conv2D)        │ (None, 7, 7, 128)      │         73,856 │ max_pooling2d_52[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_76 (Conv2D)        │ (None, 7, 7, 128)      │         73,856 │ max_pooling2d_55[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_79 (Conv2D)        │ (None, 7, 7, 128)      │         73,856 │ max_pooling2d_58[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_53          │ (None, 4, 4, 128)      │              0 │ conv2d_73[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_56          │ (None, 4, 4, 128)      │              0 │ conv2d_76[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_59          │ (None, 4, 4, 128)      │              0 │ conv2d_79[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_8             │ (None, 4, 4, 384)      │              0 │ max_pooling2d_53[0][0… │
# │ (Concatenate)             │                        │                │ max_pooling2d_56[0][0… │
# │                           │                        │                │ max_pooling2d_59[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_80 (Conv2D)        │ (None, 4, 4, 128)      │        442,496 │ concatenate_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_11          │ (None, 8, 8, 128)      │              0 │ conv2d_80[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_81 (Conv2D)        │ (None, 8, 8, 64)       │         73,792 │ up_sampling2d_11[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_85 (Conv2D)        │ (None, 4, 4, 64)       │        221,248 │ concatenate_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_12          │ (None, 16, 16, 64)     │              0 │ conv2d_81[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_84 (Conv2D)        │ (None, 4, 4, 128)      │        442,496 │ concatenate_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_10 (Flatten)      │ (None, 1024)           │              0 │ conv2d_85[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_82 (Conv2D)        │ (None, 16, 16, 32)     │         18,464 │ up_sampling2d_12[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_9 (Flatten)       │ (None, 2048)           │              0 │ conv2d_84[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_10 (Dense)          │ (None, 64)             │         65,600 │ flatten_10[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_13          │ (None, 32, 32, 32)     │              0 │ conv2d_82[0][0]        │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_9 (Dense)           │ (None, 128)            │        262,272 │ flatten_9[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 64)             │              0 │ dense_10[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_83 (Conv2D)        │ (None, 32, 32, 1)      │            289 │ up_sampling2d_13[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_class (Dense)      │ (None, 10)             │          1,290 │ dense_9[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_gender (Dense)     │ (None, 3)              │            195 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output_reconstructed      │ (None, 28, 28, 1)      │              0 │ conv2d_83[0][0]        │
# │ (Cropping2D)              │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,806,158 (6.89 MB)
#  Trainable params: 1,806,158 (6.89 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 30s 41ms/step - loss: 1.2279 - output_class_accuracy: 0.7121 - output_class_loss: 0.7764 - output_gender_accuracy: 0.8227 - output_gender_loss: 0.4132 - output_reconstructed_loss: 0.0384 - output_reconstructed_mse: 0.0384 - val_loss: 0.5340 - val_output_class_accuracy: 0.8716 - val_output_class_loss: 0.3375 - val_output_gender_accuracy: 0.9254 - val_output_gender_loss: 0.1728 - val_output_reconstructed_loss: 0.0142 - val_output_reconstructed_mse: 0.0142
# Epoch 2/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 0.4844 - output_class_accuracy: 0.8866 - output_class_loss: 0.3077 - output_gender_accuracy: 0.9372 - output_gender_loss: 0.1633 - output_reconstructed_loss: 0.0134 - output_reconstructed_mse: 0.0134 - val_loss: 0.4387 - val_output_class_accuracy: 0.8928 - val_output_class_loss: 0.2775 - val_output_gender_accuracy: 0.9396 - val_output_gender_loss: 0.1417 - val_output_reconstructed_loss: 0.0117 - val_output_reconstructed_mse: 0.0116
# Epoch 3/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.3890 - output_class_accuracy: 0.9073 - output_class_loss: 0.2494 - output_gender_accuracy: 0.9495 - output_gender_loss: 0.1282 - output_reconstructed_loss: 0.0115 - output_reconstructed_mse: 0.0115 - val_loss: 0.3713 - val_output_class_accuracy: 0.9094 - val_output_class_loss: 0.2330 - val_output_gender_accuracy: 0.9526 - val_output_gender_loss: 0.1197 - val_output_reconstructed_loss: 0.0109 - val_output_reconstructed_mse: 0.0109
# Epoch 4/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 0.3335 - output_class_accuracy: 0.9218 - output_class_loss: 0.2129 - output_gender_accuracy: 0.9561 - output_gender_loss: 0.1105 - output_reconstructed_loss: 0.0100 - output_reconstructed_mse: 0.0100 - val_loss: 0.3532 - val_output_class_accuracy: 0.9164 - val_output_class_loss: 0.2258 - val_output_gender_accuracy: 0.9540 - val_output_gender_loss: 0.1097 - val_output_reconstructed_loss: 0.0100 - val_output_reconstructed_mse: 0.0100
# Epoch 5/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.2828 - output_class_accuracy: 0.9318 - output_class_loss: 0.1797 - output_gender_accuracy: 0.9633 - output_gender_loss: 0.0936 - output_reconstructed_loss: 0.0095 - output_reconstructed_mse: 0.0095 - val_loss: 0.3505 - val_output_class_accuracy: 0.9168 - val_output_class_loss: 0.2193 - val_output_gender_accuracy: 0.9532 - val_output_gender_loss: 0.1144 - val_output_reconstructed_loss: 0.0092 - val_output_reconstructed_mse: 0.0092
# Epoch 6/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.2428 - output_class_accuracy: 0.9442 - output_class_loss: 0.1536 - output_gender_accuracy: 0.9693 - output_gender_loss: 0.0804 - output_reconstructed_loss: 0.0089 - output_reconstructed_mse: 0.0089 - val_loss: 0.3343 - val_output_class_accuracy: 0.9222 - val_output_class_loss: 0.2129 - val_output_gender_accuracy: 0.9576 - val_output_gender_loss: 0.1053 - val_output_reconstructed_loss: 0.0087 - val_output_reconstructed_mse: 0.0087
# Epoch 7/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.2144 - output_class_accuracy: 0.9497 - output_class_loss: 0.1354 - output_gender_accuracy: 0.9729 - output_gender_loss: 0.0705 - output_reconstructed_loss: 0.0086 - output_reconstructed_mse: 0.0086 - val_loss: 0.3734 - val_output_class_accuracy: 0.9176 - val_output_class_loss: 0.2269 - val_output_gender_accuracy: 0.9546 - val_output_gender_loss: 0.1296 - val_output_reconstructed_loss: 0.0084 - val_output_reconstructed_mse: 0.0084
# Epoch 8/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - loss: 0.1777 - output_class_accuracy: 0.9581 - output_class_loss: 0.1106 - output_gender_accuracy: 0.9774 - output_gender_loss: 0.0589 - output_reconstructed_loss: 0.0082 - output_reconstructed_mse: 0.0082 - val_loss: 0.3877 - val_output_class_accuracy: 0.9178 - val_output_class_loss: 0.2414 - val_output_gender_accuracy: 0.9560 - val_output_gender_loss: 0.1292 - val_output_reconstructed_loss: 0.0083 - val_output_reconstructed_mse: 0.0083
# Epoch 9/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - loss: 0.1427 - output_class_accuracy: 0.9689 - output_class_loss: 0.0875 - output_gender_accuracy: 0.9824 - output_gender_loss: 0.0472 - output_reconstructed_loss: 0.0080 - output_reconstructed_mse: 0.0080 - val_loss: 0.4108 - val_output_class_accuracy: 0.9190 - val_output_class_loss: 0.2522 - val_output_gender_accuracy: 0.9556 - val_output_gender_loss: 0.1412 - val_output_reconstructed_loss: 0.0080 - val_output_reconstructed_mse: 0.0080
# Epoch 10/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 0.1137 - output_class_accuracy: 0.9758 - output_class_loss: 0.0685 - output_gender_accuracy: 0.9856 - output_gender_loss: 0.0374 - output_reconstructed_loss: 0.0078 - output_reconstructed_mse: 0.0078 - val_loss: 0.4230 - val_output_class_accuracy: 0.9166 - val_output_class_loss: 0.2594 - val_output_gender_accuracy: 0.9538 - val_output_gender_loss: 0.1460 - val_output_reconstructed_loss: 0.0080 - val_output_reconstructed_mse: 0.0080
# Epoch 11/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 0.0913 - output_class_accuracy: 0.9791 - output_class_loss: 0.0557 - output_gender_accuracy: 0.9891 - output_gender_loss: 0.0281 - output_reconstructed_loss: 0.0076 - output_reconstructed_mse: 0.0076 - val_loss: 0.4964 - val_output_class_accuracy: 0.9164 - val_output_class_loss: 0.3173 - val_output_gender_accuracy: 0.9568 - val_output_gender_loss: 0.1598 - val_output_reconstructed_loss: 0.0078 - val_output_reconstructed_mse: 0.0077
# Epoch 12/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 0.0760 - output_class_accuracy: 0.9838 - output_class_loss: 0.0446 - output_gender_accuracy: 0.9906 - output_gender_loss: 0.0240 - output_reconstructed_loss: 0.0075 - output_reconstructed_mse: 0.0075 - val_loss: 0.5457 - val_output_class_accuracy: 0.9114 - val_output_class_loss: 0.3395 - val_output_gender_accuracy: 0.9530 - val_output_gender_loss: 0.1859 - val_output_reconstructed_loss: 0.0076 - val_output_reconstructed_mse: 0.0076
# Epoch 13/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 0.0596 - output_class_accuracy: 0.9871 - output_class_loss: 0.0347 - output_gender_accuracy: 0.9931 - output_gender_loss: 0.0175 - output_reconstructed_loss: 0.0073 - output_reconstructed_mse: 0.0073 - val_loss: 0.5602 - val_output_class_accuracy: 0.9202 - val_output_class_loss: 0.3214 - val_output_gender_accuracy: 0.9516 - val_output_gender_loss: 0.2181 - val_output_reconstructed_loss: 0.0078 - val_output_reconstructed_mse: 0.0078
# Epoch 14/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 0.0539 - output_class_accuracy: 0.9890 - output_class_loss: 0.0309 - output_gender_accuracy: 0.9941 - output_gender_loss: 0.0158 - output_reconstructed_loss: 0.0073 - output_reconstructed_mse: 0.0073 - val_loss: 0.5851 - val_output_class_accuracy: 0.9144 - val_output_class_loss: 0.3746 - val_output_gender_accuracy: 0.9530 - val_output_gender_loss: 0.1893 - val_output_reconstructed_loss: 0.0076 - val_output_reconstructed_mse: 0.0076
# Epoch 15/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 0.0510 - output_class_accuracy: 0.9901 - output_class_loss: 0.0286 - output_gender_accuracy: 0.9946 - output_gender_loss: 0.0151 - output_reconstructed_loss: 0.0073 - output_reconstructed_mse: 0.0073 - val_loss: 0.6205 - val_output_class_accuracy: 0.9194 - val_output_class_loss: 0.3823 - val_output_gender_accuracy: 0.9530 - val_output_gender_loss: 0.2162 - val_output_reconstructed_loss: 0.0076 - val_output_reconstructed_mse: 0.0076
# Epoch 16/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0476 - output_class_accuracy: 0.9919 - output_class_loss: 0.0242 - output_gender_accuracy: 0.9943 - output_gender_loss: 0.0163 - output_reconstructed_loss: 0.0071 - output_reconstructed_mse: 0.0071 - val_loss: 0.6949 - val_output_class_accuracy: 0.9138 - val_output_class_loss: 0.4078 - val_output_gender_accuracy: 0.9534 - val_output_gender_loss: 0.2634 - val_output_reconstructed_loss: 0.0076 - val_output_reconstructed_mse: 0.0076
# Epoch 17/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - loss: 0.0392 - output_class_accuracy: 0.9925 - output_class_loss: 0.0212 - output_gender_accuracy: 0.9960 - output_gender_loss: 0.0110 - output_reconstructed_loss: 0.0071 - output_reconstructed_mse: 0.0071 - val_loss: 0.6584 - val_output_class_accuracy: 0.9120 - val_output_class_loss: 0.3994 - val_output_gender_accuracy: 0.9524 - val_output_gender_loss: 0.2361 - val_output_reconstructed_loss: 0.0077 - val_output_reconstructed_mse: 0.0077
# Epoch 18/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0413 - output_class_accuracy: 0.9927 - output_class_loss: 0.0202 - output_gender_accuracy: 0.9955 - output_gender_loss: 0.0141 - output_reconstructed_loss: 0.0071 - output_reconstructed_mse: 0.0071 - val_loss: 0.6971 - val_output_class_accuracy: 0.9092 - val_output_class_loss: 0.4404 - val_output_gender_accuracy: 0.9480 - val_output_gender_loss: 0.2330 - val_output_reconstructed_loss: 0.0075 - val_output_reconstructed_mse: 0.0075
# Epoch 19/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - loss: 0.0394 - output_class_accuracy: 0.9926 - output_class_loss: 0.0218 - output_gender_accuracy: 0.9963 - output_gender_loss: 0.0105 - output_reconstructed_loss: 0.0070 - output_reconstructed_mse: 0.0070 - val_loss: 0.7386 - val_output_class_accuracy: 0.9180 - val_output_class_loss: 0.4660 - val_output_gender_accuracy: 0.9574 - val_output_gender_loss: 0.2482 - val_output_reconstructed_loss: 0.0073 - val_output_reconstructed_mse: 0.0073
# Epoch 20/20
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0268 - output_class_accuracy: 0.9953 - output_class_loss: 0.0136 - output_gender_accuracy: 0.9981 - output_gender_loss: 0.0063 - output_reconstructed_loss: 0.0069 - output_reconstructed_mse: 0.0069 - val_loss: 0.7719 - val_output_class_accuracy: 0.9122 - val_output_class_loss: 0.4542 - val_output_gender_accuracy: 0.9492 - val_output_gender_loss: 0.2924 - val_output_reconstructed_loss: 0.0074 - val_output_reconstructed_mse: 0.0074
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step
# Classification Report - Clothing Classes
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.88      0.70      0.78      1000
#      Trouser       0.98      0.98      0.98      1000
#     Pullover       0.81      0.84      0.82      1000
#        Dress       0.93      0.79      0.85      1000
#         Coat       0.73      0.87      0.80      1000
#       Sandal       0.95      0.97      0.96      1000
#        Shirt       0.59      0.68      0.63      1000
#      Sneaker       0.98      0.86      0.92      1000
#          Bag       0.94      0.99      0.96      1000
#   Ankle boot       0.91      0.97      0.94      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.87      0.86      0.86     10000
# weighted avg       0.87      0.86      0.86     10000
# Classification Report - Gender Classes
#               precision    recall  f1-score   support
#
#    Masculino       0.30      0.33      0.31      3011
#     Femenino       0.30      0.30      0.30      2998
#       Neutro       0.39      0.36      0.38      3991
#
#     accuracy                           0.33     10000
#    macro avg       0.33      0.33      0.33     10000
# weighted avg       0.34      0.33      0.34     10000
